# %%
using CapAndHomalg
# Out:
# CapAndHomalg v1.6.8
# Imported OSCAR's components GAP and Singular_jll
# Type: ?CapAndHomalg for more information

# %%
LoadPackage( "FinGSetsForCAP" )

# %%
S4 = SymmetricGroup( 4 ); StructureDescription( S4 )
# Out:
# GAP: "S4"

# %%
S4
# Out:
# GAP: S4

# %%
TS4 = SkeletalCategoryOfTransitiveGSets( S4 )
# Out:
# GAP: SkeletalCategoryOfTransitiveGSets( S4 ) with 11 objects

# %%
Display( TS4 )
# Out:
# A CAP category with name SkeletalCategoryOfTransitiveGSets( S4 ) with 11 objects:
#
# 24 primitive operations were used to derive 71 operations for this category which algorithmically
# * IsCategoryWithDecidableColifts
# * IsCategoryWithDecidableLifts
# * IsCategoryWithTerminalObject
# * IsFiniteCategory
# * IsCategoryWithCoequalizers
# * IsEquippedWithHomomorphismStructure
# and furthermore mathematically
# * IsSkeletalCategory

# %%
LoadPackage( "Locales" )

# %%
PTS4 = PosetOfCategory( TS4 )
# Out:
# GAP: PosetOfCategory( SkeletalCategoryOfTransitiveGSets( S4 ) with 11 objects )

# %%
#DigraphOfPoset( PTS4 )

# %% [markdown]
# <img src="svg/PTS4.svg" alt="drawing" width="200"/>
